# %%
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
files_df = pd.read_csv('train_resized.csv')
names = files_df.category.unique()
names
# Out:
# array(['Black-grass', 'Charlock', 'Cleavers', 'Common Chickweed',
#        'Common wheat', 'Fat Hen', 'Loose Silky-bent', 'Maize',
#        'Scentless Mayweed', 'Shepherds Purse',
#        'Small-flowered Cranesbill', 'Sugar beet'], dtype=object)

# %%
n = 3
fig, axes = plt.subplots(12, n*2, figsize=(24, 32))
for i, name in enumerate(names):
    f = files_df[files_df.category == name].sample(n).filename.values
    for j in range(0, n*2, 2):
        fns = [f[j//2].replace('train_256x256x3', 'train'), f[j//2]]
        for jj, fn in zip(range(j, j+2), fns):
            im = plt.imread(fn)
            axes[i][jj].imshow(im)
            axes[i][jj].axis('off')
            axes[i][jj].set_title(name + ' ' + str(im.shape))
